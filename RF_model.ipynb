# %% [markdown]
# DATA PROCESSING

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('data.csv')
data.head()
# Out:
#    Wellhead_Temp. (C)  Wellhead_Press (psi)  MMCFD- gas  \
# 0           51.088486           1364.601753    6.784434
# 1           51.096512           1474.635955   11.280674
# 2           57.631303           1233.116598    8.786931
# 3           55.413455           1564.958133   10.793411
# 4           36.821261           1500.806676   12.748623
#
#    BOPD (barrel of oil produced per day)  \
# 0                             404.673699
# 1                             364.764774
# 2                             414.652564
# 3                             511.357422
# 4                             537.593023
#
#    BWPD (barrel of water produced per day)  BSW basic solid and water(%)  \
# 0                               293.125995                      5.265676
# 1                               208.472370                      5.331766
# 2                               228.530184                      5.696270
# 3                               161.711604                      6.073352
# 4                               185.303039                      4.867634
#
#    CO2 mol. (%) @ 25C & 1 Atm  Gas Grav  CR-corrosion defect  leak_status
# 0                    1.038911  0.601146             0.144365          1.0
# 1                    0.961022  0.618705             0.135026          0.0
# 2                    1.295514  0.712029             0.154846          1.0
# 3                    0.801719  0.640946             0.108198          0.0
# 4                    1.049567  0.644026             0.114479          0.0

# %%
print(data.isnull().sum())
# Out:
# Wellhead_Temp. (C)                         0
# Wellhead_Press (psi)                       0
# MMCFD- gas                                 0
# BOPD (barrel of oil produced per day)      0
# BWPD (barrel of water produced per day)    0
# BSW basic solid and water(%)               0
# CO2 mol. (%) @ 25C & 1 Atm                 0
# Gas Grav                                   0
# CR-corrosion defect                        0
# leak_status                                0
# dtype: int64

# %% [markdown]
# FEATURES AND TARGET

# %%
X = data.drop('leak_status', axis=1)
y = data['leak_status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print('done')
# Out:
# done

# %% [markdown]
# PARAMETER TUNING

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from scipy.stats import randint


param_dist = {
    'n_estimators': randint(10, 200),
    'max_depth': randint(1, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'bootstrap': [True, False]
}


rf_model = RandomForestClassifier()

random_search = RandomizedSearchCV(estimator=rf_model, param_distributions=param_dist, n_iter=100, cv=5, verbose=2, n_jobs=-1, random_state=42)

random_search.fit(X_train, y_train)

print("Best Parameters:", random_search.best_params_)
print("Best Score:", random_search.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=19, min_samples_split=12, n_estimators=97; total time=   1.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=19, min_samples_split=12, n_estimators=97; total time=   1.7s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=19, min_samples_split=12, n_estimators=97; total time=   1.7s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=19, min_samples_split=12, n_estimators=97; total time=   1.6s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=19, min_samples_split=12, n_estimators=97; total time=   1.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=8, min_samples_split=4, n_estimators=159; total time=   1.8s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=11, min_samples_split=9, n_estimators=198; total time=   3.8s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=11, min_samples_split=9, n_estimators=198; total time=   3.9s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=11, min_samples_split=9, n_estimators=198; total time=   4.0s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=11, min_samples_split=9, n_estimators=198; total time=   4.3s
# [CV] END bootstrap=True, max_depth=15, min_samples_leaf=11, min_samples_split=9, n_estimators=198; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=139; total time=   1.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=8, min_samples_split=4, n_estimators=159; total time=   1.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=8, min_samples_split=4, n_estimators=159; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=139; total time=   1.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=12, min_samples_split=13, n_estimators=98; total time=   0.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=8, min_samples_split=4, n_estimators=159; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=139; total time=   1.3s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=139; total time=   1.4s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=8, min_samples_split=4, n_estimators=159; total time=   2.7s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=12, min_samples_split=13, n_estimators=98; total time=   0.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=139; total time=   1.0s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=12, min_samples_split=13, n_estimators=98; total time=   0.5s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=12, min_samples_split=13, n_estimators=98; total time=   0.5s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=12, min_samples_split=13, n_estimators=98; total time=   0.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=19, min_samples_split=13, n_estimators=64; total time=   1.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=19, min_samples_split=13, n_estimators=64; total time=   1.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=19, min_samples_split=13, n_estimators=64; total time=   2.3s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   3.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=19, min_samples_split=13, n_estimators=64; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   3.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=19, min_samples_split=13, n_estimators=64; total time=   1.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.4s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.5s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   4.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   4.7s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   4.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=18, min_samples_split=5, n_estimators=98; total time=   1.7s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=18, min_samples_split=5, n_estimators=98; total time=   2.2s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=18, min_samples_split=5, n_estimators=98; total time=   2.2s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=18, min_samples_split=5, n_estimators=98; total time=   2.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=18, min_samples_split=5, n_estimators=98; total time=   2.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=18, min_samples_split=10, n_estimators=99; total time=   2.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=18, min_samples_split=10, n_estimators=99; total time=   2.8s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=18, min_samples_split=10, n_estimators=99; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=15, min_samples_split=8, n_estimators=181; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=15, min_samples_split=8, n_estimators=181; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=15, min_samples_split=8, n_estimators=181; total time=   2.0s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=18, min_samples_split=10, n_estimators=99; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=15, min_samples_split=8, n_estimators=181; total time=   1.4s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=15, min_samples_split=8, n_estimators=181; total time=   1.6s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=15, min_samples_split=4, n_estimators=90; total time=   1.7s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=5, n_estimators=11; total time=   0.4s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=5, n_estimators=11; total time=   0.4s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=5, n_estimators=11; total time=   0.5s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=5, n_estimators=11; total time=   0.4s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=18, min_samples_split=10, n_estimators=99; total time=   3.8s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=8, min_samples_split=5, n_estimators=11; total time=   0.4s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=15, min_samples_split=4, n_estimators=90; total time=   2.2s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=15, min_samples_split=4, n_estimators=90; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=15, min_samples_split=4, n_estimators=90; total time=   2.1s
# [CV] END bootstrap=True, max_depth=8, min_samples_leaf=15, min_samples_split=4, n_estimators=90; total time=   2.0s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   1.5s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   1.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   1.8s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   1.4s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=10, min_samples_split=5, n_estimators=63; total time=   1.8s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=12, min_samples_split=3, n_estimators=199; total time=   4.7s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=12, min_samples_split=3, n_estimators=199; total time=   4.6s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=12, min_samples_split=3, n_estimators=199; total time=   4.5s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=12, min_samples_split=3, n_estimators=199; total time=   4.5s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=12, min_samples_split=3, n_estimators=199; total time=   4.4s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   6.5s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   6.4s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   6.3s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=13, min_samples_split=19, n_estimators=120; total time=   3.9s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=16, n_estimators=54; total time=   1.2s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=13, min_samples_split=19, n_estimators=120; total time=   3.9s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=13, min_samples_split=19, n_estimators=120; total time=   3.9s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=16, n_estimators=54; total time=   1.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=16, n_estimators=54; total time=   1.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=16, n_estimators=54; total time=   1.3s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=16, n_estimators=54; total time=   1.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   6.2s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=16, min_samples_split=16, n_estimators=199; total time=   6.2s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=13, min_samples_split=19, n_estimators=120; total time=   3.8s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=13, min_samples_split=19, n_estimators=120; total time=   3.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=145; total time=   2.7s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=145; total time=   2.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=145; total time=   2.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=145; total time=   2.8s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=145; total time=   2.8s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.5s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=1, min_samples_split=6, n_estimators=50; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=21; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=21; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=21; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=21; total time=   0.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=9, n_estimators=21; total time=   0.6s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=19, min_samples_split=18, n_estimators=145; total time=   4.5s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=16, min_samples_split=6, n_estimators=108; total time=   0.7s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=19, min_samples_split=18, n_estimators=145; total time=   4.5s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=19, min_samples_split=18, n_estimators=145; total time=   4.6s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=16, min_samples_split=6, n_estimators=108; total time=   0.7s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=16, min_samples_split=6, n_estimators=108; total time=   0.7s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=16, min_samples_split=6, n_estimators=108; total time=   0.7s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=16, min_samples_split=6, n_estimators=108; total time=   0.7s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=19, min_samples_split=18, n_estimators=145; total time=   4.5s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=19, min_samples_split=18, n_estimators=145; total time=   4.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=3, min_samples_split=2, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=10, n_estimators=24; total time=   0.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=10, n_estimators=24; total time=   0.9s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=10, n_estimators=24; total time=   0.9s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=3, min_samples_split=2, n_estimators=110; total time=   3.2s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=3, min_samples_split=2, n_estimators=110; total time=   3.3s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=3, min_samples_split=2, n_estimators=110; total time=   3.3s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=10, n_estimators=24; total time=   0.8s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=3, min_samples_split=2, n_estimators=110; total time=   3.2s
# [CV] END bootstrap=False, max_depth=14, min_samples_leaf=7, min_samples_split=10, n_estimators=24; total time=   0.8s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=3, min_samples_split=2, n_estimators=110; total time=   3.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=8, n_estimators=61; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=8, n_estimators=61; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=8, n_estimators=61; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=8, n_estimators=61; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=13, min_samples_split=8, n_estimators=61; total time=   2.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=8, n_estimators=152; total time=   2.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=8, n_estimators=152; total time=   2.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=8, n_estimators=152; total time=   2.1s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=10, min_samples_split=14, n_estimators=71; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=8, n_estimators=152; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=10, min_samples_split=14, n_estimators=71; total time=   0.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=5, min_samples_split=8, n_estimators=152; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=10, min_samples_split=14, n_estimators=71; total time=   0.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=10, min_samples_split=14, n_estimators=71; total time=   0.6s
# [CV] END bootstrap=True, max_depth=2, min_samples_leaf=10, min_samples_split=14, n_estimators=71; total time=   0.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=8, n_estimators=196; total time=   2.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=8, n_estimators=196; total time=   2.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=8, n_estimators=196; total time=   2.5s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=8, n_estimators=196; total time=   2.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=13, min_samples_split=8, n_estimators=196; total time=   2.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=13, n_estimators=93; total time=   1.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=13, n_estimators=93; total time=   1.7s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=13, n_estimators=93; total time=   1.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=13, n_estimators=93; total time=   1.6s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=12, min_samples_split=13, n_estimators=93; total time=   1.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=112; total time=   2.7s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=112; total time=   2.8s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=112; total time=   2.8s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=138; total time=   5.0s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=138; total time=   5.1s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=138; total time=   5.0s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=6, n_estimators=60; total time=   1.9s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=138; total time=   5.1s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=7, min_samples_split=2, n_estimators=138; total time=   5.0s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=6, n_estimators=60; total time=   1.9s
# [CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=112; total time=   2.8s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=6, n_estimators=60; total time=   2.0s[CV] END bootstrap=True, max_depth=13, min_samples_leaf=9, min_samples_split=4, n_estimators=112; total time=   2.8s
#
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=6, n_estimators=60; total time=   2.0s
# [CV] END bootstrap=False, max_depth=8, min_samples_leaf=9, min_samples_split=6, n_estimators=60; total time=   2.0s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=12, min_samples_split=8, n_estimators=139; total time=   3.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=12, min_samples_split=8, n_estimators=139; total time=   3.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=12, min_samples_split=8, n_estimators=139; total time=   3.5s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=15, min_samples_split=10, n_estimators=189; total time=   7.1s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=15, min_samples_split=10, n_estimators=189; total time=   7.1s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=15, min_samples_split=10, n_estimators=189; total time=   6.8s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=15, min_samples_split=10, n_estimators=189; total time=   6.9s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=15, min_samples_split=10, n_estimators=189; total time=   6.9s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=12, min_samples_split=8, n_estimators=139; total time=   3.6s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=12, min_samples_split=8, n_estimators=139; total time=   3.8s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=2, min_samples_split=3, n_estimators=63; total time=   2.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=2, min_samples_split=3, n_estimators=63; total time=   2.3s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=2, min_samples_split=3, n_estimators=63; total time=   2.6s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=2, min_samples_split=3, n_estimators=63; total time=   2.2s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=5, min_samples_split=18, n_estimators=193; total time=   6.6s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=2, min_samples_split=3, n_estimators=63; total time=   2.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=5, min_samples_split=18, n_estimators=193; total time=   5.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=5, min_samples_split=18, n_estimators=193; total time=   6.0s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=156; total time=   3.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=5, min_samples_split=18, n_estimators=193; total time=   6.6s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=5, min_samples_split=18, n_estimators=193; total time=   6.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=169; total time=   1.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=156; total time=   2.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=156; total time=   2.9s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=156; total time=   2.7s
# [CV] END bootstrap=True, max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=156; total time=   2.6s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=11, min_samples_split=18, n_estimators=47; total time=   0.7s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=11, min_samples_split=18, n_estimators=47; total time=   0.8s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=11, min_samples_split=18, n_estimators=47; total time=   0.7s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=169; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=169; total time=   2.1s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=11, min_samples_split=18, n_estimators=47; total time=   0.7s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=169; total time=   2.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=11, min_samples_split=18, n_estimators=47; total time=   0.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=12, min_samples_split=7, n_estimators=169; total time=   2.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=7, n_estimators=148; total time=   3.7s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=16, min_samples_split=2, n_estimators=133; total time=   3.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=7, n_estimators=148; total time=   3.7s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=16, min_samples_split=2, n_estimators=133; total time=   3.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=7, n_estimators=148; total time=   4.4s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=7, n_estimators=148; total time=   4.6s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=2, min_samples_split=7, n_estimators=148; total time=   4.6s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=16, min_samples_split=2, n_estimators=133; total time=   4.2s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=16, min_samples_split=2, n_estimators=133; total time=   3.4s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=16, min_samples_split=4, n_estimators=157; total time=   3.1s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=16, min_samples_split=2, n_estimators=133; total time=   3.2s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=16, min_samples_split=4, n_estimators=157; total time=   3.2s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=16, min_samples_split=4, n_estimators=157; total time=   3.8s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=16, min_samples_split=4, n_estimators=157; total time=   4.3s
# [CV] END bootstrap=True, max_depth=6, min_samples_leaf=16, min_samples_split=4, n_estimators=157; total time=   4.1s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=19, min_samples_split=4, n_estimators=156; total time=   3.9s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=19, min_samples_split=4, n_estimators=156; total time=   3.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=19, min_samples_split=4, n_estimators=156; total time=   3.4s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=19, min_samples_split=4, n_estimators=156; total time=   3.5s
# [CV] END bootstrap=False, max_depth=4, min_samples_leaf=19, min_samples_split=4, n_estimators=156; total time=   3.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=18, min_samples_split=9, n_estimators=138; total time=   4.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=177; total time=   5.6s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=18, min_samples_split=9, n_estimators=138; total time=   4.2s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=177; total time=   6.7s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=177; total time=   6.5s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=10, min_samples_split=4, n_estimators=16; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=177; total time=   6.5s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=10, min_samples_split=4, n_estimators=16; total time=   0.6s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=10, min_samples_split=4, n_estimators=16; total time=   0.5s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=10, min_samples_split=4, n_estimators=16; total time=   0.4s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=9, min_samples_split=2, n_estimators=177; total time=   5.6s
# [CV] END bootstrap=True, max_depth=18, min_samples_leaf=10, min_samples_split=4, n_estimators=16; total time=   0.5s
# [CV] END bootstrap=False, max_depth=7, min_samples_leaf=18, min_samples_split=9, n_estimators=138; total time=   5.6s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=16, min_samples_split=18, n_estimators=11; total time=   0.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=16, min_samples_split=18, n_estimators=11; total time=   0.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=16, min_samples_split=18, n_estimators=11; total time=   0.4s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf

# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=19, min_samples_split=16, n_estimators=101; total time=   4.0s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=7, min_samples_split=5, n_estimators=182; total time=   7.9s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=7, min_samples_split=5, n_estimators=182; total time=   7.9s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=19, min_samples_split=16, n_estimators=101; total time=   4.0s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=18, n_estimators=189; total time=   2.9s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=19, min_samples_split=16, n_estimators=101; total time=   4.9s
# [CV] END bootstrap=False, max_depth=12, min_samples_leaf=19, min_samples_split=16, n_estimators=101; total time=   5.2s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=18, n_estimators=189; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=18, n_estimators=189; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=18, n_estimators=189; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=18, n_estimators=189; total time=   3.3s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=13, n_estimators=117; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=13, n_estimators=117; total time=   1.1s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=13, n_estimators=117; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=13, n_estimators=117; total time=   1.2s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=8, min_samples_split=13, n_estimators=117; total time=   1.1s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=15, min_samples_split=12, n_estimators=197; total time=   6.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=7, n_estimators=118; total time=   3.5s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=15, min_samples_split=12, n_estimators=197; total time=   6.8s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=15, min_samples_split=12, n_estimators=197; total time=   7.0s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=7, n_estimators=118; total time=   3.4s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=7, n_estimators=118; total time=   3.2s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=15, min_samples_split=12, n_estimators=197; total time=   6.9s
# [CV] END bootstrap=False, max_depth=6, min_samples_leaf=15, min_samples_split=12, n_estimators=197; total time=   6.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=7, n_estimators=118; total time=   2.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=3, min_samples_split=9, n_estimators=61; total time=   2.6s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=7, n_estimators=118; total time=   2.8s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=3, min_samples_split=9, n_estimators=61; total time=   2.9s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=3, min_samples_split=9, n_estimators=61; total time=   2.8s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=3, min_samples_split=9, n_estimators=61; total time=   2.7s
# [CV] END bootstrap=False, max_depth=15, min_samples_leaf=3, min_samples_split=9, n_estimators=61; total time=   2.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=19, min_samples_split=6, n_estimators=126; total time=   3.5s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=19, min_samples_split=6, n_estimators=126; total time=   3.2s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=19, min_samples_split=6, n_estimators=126; total time=   3.6s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=18, min_samples_split=11, n_estimators=167; total time=   6.7s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=18, min_samples_split=11, n_estimators=167; total time=   6.2s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=18, min_samples_split=11, n_estimators=167; total time=   5.9s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=18, min_samples_split=11, n_estimators=167; total time=   6.3s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=12, min_samples_split=2, n_estimators=67; total time=   2.8s
# [CV] END bootstrap=False, max_depth=13, min_samples_leaf=18, min_samples_split=11, n_estimators=167; total time=   6.8s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=19, min_samples_split=6, n_estimators=126; total time=   3.4s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=19, min_samples_split=6, n_estimators=126; total time=   3.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=15, min_samples_split=3, n_estimators=105; total time=   1.1s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=12, min_samples_split=2, n_estimators=67; total time=   2.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=12, min_samples_split=2, n_estimators=67; total time=   2.3s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=15, min_samples_split=3, n_estimators=105; total time=   0.8s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=12, min_samples_split=2, n_estimators=67; total time=   2.8s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=15, min_samples_split=3, n_estimators=105; total time=   1.3s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=15, min_samples_split=3, n_estimators=105; total time=   1.4s
# [CV] END bootstrap=False, max_depth=9, min_samples_leaf=12, min_samples_split=2, n_estimators=67; total time=   2.4s
# [CV] END bootstrap=False, max_depth=1, min_samples_leaf=15, min_samples_split=3, n_estimators=105; total time=   1.3s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=6, n_estimators=31; total time=   0.9s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=6, n_estimators=31; total time=   1.4s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=6, n_estimators=31; total time=   0.8s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=6, n_estimators=31; total time=   1.3s
# [CV] END bootstrap=True, max_depth=16, min_samples_leaf=7, min_samples_split=6, n_estimators=31; total time=   1.2s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=12, min_samples_split=17, n_estimators=188; total time=   2.5s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=8, min_samples_split=14, n_estimators=126; total time=   5.3s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=8, min_samples_split=14, n_estimators=126; total time=   5.4s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=8, min_samples_split=14, n_estimators=126; total time=   5.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=12, min_samples_split=17, n_estimators=188; total time=   3.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=12, min_samples_split=17, n_estimators=188; total time=   4.2s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=12, min_samples_split=17, n_estimators=188; total time=   2.6s
# [CV] END bootstrap=True, max_depth=3, min_samples_leaf=12, min_samples_split=17, n_estimators=188; total time=   2.6s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=8, min_samples_split=14, n_estimators=126; total time=   8.7s
# [CV] END bootstrap=False, max_depth=16, min_samples_leaf=8, min_samples_split=14, n_estimators=126; total time=   8.7s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=16, n_estimators=103; total time=   3.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=16, n_estimators=103; total time=   3.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=16, n_estimators=103; total time=   3.2s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=16, n_estimators=103; total time=   5.8s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=5, min_samples_split=16, n_estimators=103; total time=   5.1s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   5.1s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=110; total time=   2.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   4.9s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   5.0s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=110; total time=   3.2s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   6.0s
# [CV] END bootstrap=False, max_depth=5, min_samples_leaf=12, min_samples_split=17, n_estimators=185; total time=   6.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=43; total time=   1.3s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=110; total time=   2.9s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=43; total time=   1.2s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=43; total time=   1.2s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=110; total time=   2.8s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=43; total time=   1.5s
# [CV] END bootstrap=True, max_depth=10, min_samples_leaf=5, min_samples_split=5, n_estimators=43; total time=   1.5s
# [CV] END bootstrap=True, max_depth=7, min_samples_leaf=4, min_samples_split=2, n_estimators=110; total time=   3.0s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=16, min_samples_split=17, n_estimators=11; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=16, min_samples_split=17, n_estimators=11; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=16, min_samples_split=17, n_estimators=11; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=16, min_samples_split=17, n_estimators=11; total time=   0.2s
# [CV] END bootstrap=True, max_depth=4, min_samples_leaf=16, min_samples_split=17, n_estimators=11; total time=   0.3s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=19, min_samples_split=2, n_estimators=78; total time=   3.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=19, min_samples_split=2, n_estimators=78; total time=   3.7s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=19, min_samples_split=2, n_estimators=78; total time=   3.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=19, min_samples_split=2, n_estimators=78; total time=   3.6s
# [CV] END bootstrap=False, max_depth=10, min_samples_leaf=19, min_samples_split=2, n_estimators=78; total time=   3.8s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=19, min_samples_split=12, n_estimators=110; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=19, min_samples_split=12, n_estimators=110; total time=   1.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=19, min_samples_split=12, n_estimators=110; total time=   0.9s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=18, min_samples_split=4, n_estimators=133; total time=   4.0s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=19, min_samples_split=12, n_estimators=110; total time=   0.9s
# [CV] END bootstrap=True, max_depth=1, min_samples_leaf=19, min_samples_split=12, n_estimators=110; total time=   0.9s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=18, min_samples_split=4, n_estimators=133; total time=   4.3s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=18, min_samples_split=4, n_estimators=133; total time=   4.4s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=12, min_samples_split=14, n_estimators=21; total time=   0.9s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=18, min_samples_split=4, n_estimators=133; total time=   3.7s
# [CV] END bootstrap=True, max_depth=12, min_samples_leaf=18, min_samples_split=4, n_estimators=133; total time=   4.0s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=12, min_samples_split=14, n_estimators=21; total time=   0.9s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=12, min_samples_split=14, n_estimators=21; total time=   0.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=177; total time=   3.0s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=177; total time=   3.0s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=12, min_samples_split=14, n_estimators=21; total time=   0.8s
# [CV] END bootstrap=False, max_depth=11, min_samples_leaf=12, min_samples_split=14, n_estimators=21; total time=   0.8s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=177; total time=   2.9s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=177; total time=   3.0s
# [CV] END bootstrap=False, max_depth=3, min_samples_leaf=1, min_samples_split=2, n_estimators=177; total time=   3.2s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=2, min_samples_split=19, n_estimators=44; total time=   1.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=2, min_samples_split=19, n_estimators=44; total time=   1.3s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=2, min_samples_split=19, n_estimators=44; total time=   1.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=2, min_samples_split=19, n_estimators=44; total time=   1.4s
# [CV] END bootstrap=True, max_depth=14, min_samples_leaf=2, min_samples_split=19, n_estimators=44; total time=   1.5s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=10, n_estimators=144; total time=   1.7s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=8, min_samples_split=11, n_estimators=99; total time=   2.9s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=10, n_estimators=144; total time=   1.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=10, n_estimators=144; total time=   1.8s[CV] END bootstrap=True, max_depth=17, min_samples_leaf=8, min_samples_split=11, n_estimators=99; total time=   2.9s
#
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=8, min_samples_split=11, n_estimators=99; total time=   3.1s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=8, min_samples_split=11, n_estimators=99; total time=   2.8s
# [CV] END bootstrap=True, max_depth=17, min_samples_leaf=8, min_samples_split=11, n_estimators=99; total time=   2.8s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=10, n_estimators=144; total time=   1.6s
# [CV] END bootstrap=False, max_depth=2, min_samples_leaf=19, min_samples_split=10, n_estimators=144; total time=   1.5s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=13, min_samples_split=12, n_estimators=166; total time=   5.3s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=13, min_samples_split=12, n_estimators=166; total time=   5.4s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=13, min_samples_split=12, n_estimators=166; total time=   5.4s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=13, min_samples_split=12, n_estimators=166; total time=   5.3s
# [CV] END bootstrap=False, max_depth=18, min_samples_leaf=13, min_samples_split=12, n_estimators=166; total time=   5.6s
# Best Parameters: {'bootstrap': True, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 19, 'n_estimators': 44}
# Best Score: 0.8348571428571429

# %%
best_params = random_search.best_params_
print("Best Parameters:", best_params)
print("Best Score:", random_search.best_score_)
# Out:
# Best Parameters: {'bootstrap': True, 'max_depth': 14, 'min_samples_leaf': 2, 'min_samples_split': 19, 'n_estimators': 44}
# Best Score: 0.8348571428571429

# %% [markdown]
# MODEL TRAINNING

# %%
model = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    bootstrap=best_params['bootstrap']
)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=14, min_samples_leaf=2, min_samples_split=19,
#                        n_estimators=44)

# %% [markdown]
# SAVE MODEL

# %%
import pickle

with open('rf_model.pkl', 'wb') as f:
    pickle.dump(model, f)

print('done')
# Out:
# done

# %% [markdown]
# MODEL EVALUATION

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

with open('rf_model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

y_pred = loaded_model.predict(X_test)
y_pred_proba = loaded_model.predict_proba(X_test)

# %% [markdown]
# CONFUSION MATRIX

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1476   60    0    0]
#  [ 137  384   68    0]
#  [   4   78  469   42]
#  [   0    0   67  215]]

# %% [markdown]
# CLASSIFICATION REPORT

# %%
class_report = classification_report(y_test, y_pred, target_names=['Normal', 'Minor Leak', 'Moderate Leak', 'Severe Leak'])
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        Normal       0.91      0.96      0.94      1536
#    Minor Leak       0.74      0.65      0.69       589
# Moderate Leak       0.78      0.79      0.78       593
#   Severe Leak       0.84      0.76      0.80       282
#
#      accuracy                           0.85      3000
#     macro avg       0.82      0.79      0.80      3000
#  weighted avg       0.84      0.85      0.84      3000

# %% [markdown]
# ROC-AUC SCORE

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.9610537219617605
