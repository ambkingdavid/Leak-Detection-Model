# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
import os


# Suppress TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
df = pd.read_csv('generated_dataset.csv')

# Binning Target
percentile = 0.8
threshold = df['CR-corrosion defect'].quantile(percentile)
df['Leak_Status'] = np.where(df['CR-corrosion defect'] > threshold, 'Leak', 'No Leak')

le = LabelEncoder()
y = le.fit_transform(df['Leak_Status'])

X = df.drop(['CR-corrosion defect', 'Leak_Status'], axis=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# LSTM expects 3D input: (samples, timesteps, features)
# For tabular data, use timesteps=1
X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))

# One-hot encode target for Keras
y_cat = to_categorical(y)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_cat, test_size=0.2, random_state=42)

# %%
model = Sequential([
    LSTM(32, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(y_cat.shape[1], activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# /home/Leak-Detection-Model/venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7797 - loss: 0.5476 - val_accuracy: 0.7923 - val_loss: 0.3801
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8125 - loss: 0.3639 - val_accuracy: 0.8877 - val_loss: 0.3014
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8954 - loss: 0.2912 - val_accuracy: 0.9338 - val_loss: 0.2083
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9230 - loss: 0.2146 - val_accuracy: 0.9587 - val_loss: 0.1701
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9305 - loss: 0.1966 - val_accuracy: 0.9636 - val_loss: 0.1560
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9370 - loss: 0.1843 - val_accuracy: 0.9605 - val_loss: 0.1484
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9410 - loss: 0.1662 - val_accuracy: 0.9684 - val_loss: 0.1395
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9429 - loss: 0.1608 - val_accuracy: 0.9696 - val_loss: 0.1376
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9442 - loss: 0.1654 - val_accuracy: 0.9678 - val_loss: 0.1350
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9495 - loss: 0.1531 - val_accuracy: 0.9696 - val_loss: 0.1311
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9514 - loss: 0.1496 - val_accuracy: 0.9721 - val_loss: 0.1288
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9515 - loss: 0.1444 - val_accuracy: 0.9739 - val_loss: 0.1256
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9490 - loss: 0.1577 - val_accuracy: 0.9715 - val_loss: 0.1228
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9579 - loss: 0.1387 - val_accuracy: 0.9727 - val_loss: 0.1193
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9491 - loss: 0.1430 - val_accuracy: 0.9757 - val_loss: 0.1197
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9610 - loss: 0.1307 - val_accuracy: 0.9739 - val_loss: 0.1172
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9487 - loss: 0.1368 - val_accuracy: 0.9745 - val_loss: 0.1154
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9565 - loss: 0.1308 - val_accuracy: 0.9745 - val_loss: 0.1162
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9490 - loss: 0.1496 - val_accuracy: 0.9727 - val_loss: 0.1137
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9539 - loss: 0.1364 - val_accuracy: 0.9733 - val_loss: 0.1123
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9599 - loss: 0.1307 - val_accuracy: 0.9739 - val_loss: 0.1119
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9533 - loss: 0.1344 - val_accuracy: 0.9769 - val_loss: 0.1093
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9596 - loss: 0.1395 - val_accuracy: 0.9751 - val_loss: 0.1096
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9558 - loss: 0.1403 - val_accuracy: 0.9763 - val_loss: 0.1080
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9560 - loss: 0.1388 - val_accuracy: 0.9763 - val_loss: 0.1077
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9518 - loss: 0.1380 - val_accuracy: 0.9715 - val_loss: 0.1097
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9558 - loss: 0.1321 - val_accuracy: 0.9721 - val_loss: 0.1072
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9554 - loss: 0.1314 - val_accuracy: 0.9769 - val_loss: 0.1055
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9602 - loss: 0.1243 - val_accuracy: 0.9775 - val_loss: 0.1042
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9630 - loss: 0.1206 - val_accuracy: 0.9775 - val_loss: 0.1039
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9598 - loss: 0.1275 - val_accuracy: 0.9763 - val_loss: 0.1019
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9621 - loss: 0.1247 - val_accuracy: 0.9757 - val_loss: 0.1028
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9562 - loss: 0.1277 - val_accuracy: 0.9787 - val_loss: 0.1007
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9557 - loss: 0.1244 - val_accuracy: 0.9781 - val_loss: 0.1012
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9614 - loss: 0.1192 - val_accuracy: 0.9745 - val_loss: 0.1035
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9563 - loss: 0.1314 - val_accuracy: 0.9763 - val_loss: 0.1014
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9573 - loss: 0.1302 - val_accuracy: 0.9787 - val_loss: 0.1009
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9660 - loss: 0.1157 - val_accuracy: 0.9794 - val_loss: 0.1003
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9599 - loss: 0.1192 - val_accuracy: 0.9781 - val_loss: 0.0989
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9620 - loss: 0.1152 - val_accuracy: 0.9769 - val_loss: 0.0988
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9610 - loss: 0.1265 - val_accuracy: 0.9769 - val_loss: 0.1004
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9591 - loss: 0.1217 - val_accuracy: 0.9763 - val_loss: 0.1003
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9630 - loss: 0.1158 - val_accuracy: 0.9781 - val_loss: 0.0987
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9590 - loss: 0.1169 - val_accuracy: 0.9769 - val_loss: 0.0978
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9592 - loss: 0.1175 - val_accuracy: 0.9787 - val_loss: 0.0974
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9638 - loss: 0.1159 - val_accuracy: 0.9763 - val_loss: 0.0984
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9601 - loss: 0.1161 - val_accuracy: 0.9763 - val_loss: 0.0980
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9576 - loss: 0.1261 - val_accuracy: 0.9739 - val_loss: 0.0986
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9657 - loss: 0.1134 - val_accuracy: 0.9769 - val_loss: 0.1004
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9623 - loss: 0.1156 - val_accuracy: 0.9751 - val_loss: 0.0977

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# Predict and classification report
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

print(classification_report(y_true, y_pred_classes, target_names=le.classes_))
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.1343
# Test Accuracy: 0.9704
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#               precision    recall  f1-score   support
#
#         Leak       0.95      0.89      0.92       377
#      No Leak       0.97      0.99      0.98      1682
#
#     accuracy                           0.97      2059
#    macro avg       0.96      0.94      0.95      2059
# weighted avg       0.97      0.97      0.97      2059

# %%
model.save("lstm_leak_detection_model.keras")

# %%
from tensorflow.keras.models import load_model


# Load the model and scaler for prediction
model = load_model("lstm_leak_detection_model.keras", compile=False)

# Example prediction
example = pd.DataFrame([{
    'Wellhead Temp. (C)': 85,
    'Wellhead Press (psi)': 2500,
    'MMCFD- gas': 12,
    'BOPD (barrel of oil produced per day)': 500,
    'BWPD (barrel of water produced per day)': 200,
    'BSW - basic solid and water (%)': 5,
    'CO2 mol. (%) @ 25 C & 1 Atm.': 2.5,
    'Gas Grav.': 0.7
}])

example_scaled = scaler.transform(example).reshape((1, 1, X.shape[1]))
pred = model.predict(example_scaled)

# Display probability for each class in percentage
for label, prob in zip(le.classes_, pred[0]):
    print(f"Probability of {label}: {prob * 100:.2f}%")

# Display predicted class as before
pred_label = le.inverse_transform([np.argmax(pred)])
print("Predicted Leak Status:", pred_label[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Probability of Leak: 1.81%
# Probability of No Leak: 98.19%
# Predicted Leak Status: No Leak
